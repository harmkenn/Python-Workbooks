# %%
import scrapy
from scrapy.crawler import CrawlerProcess
import pandas as pd
from twisted.internet import reactor

class BestJobsSpider(scrapy.Spider):
    name = 'best_jobs'
    start_urls = ['https://money.usnews.com/careers/best-jobs/search']

    def start_requests(self):
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
        for url in self.start_urls:
            yield scrapy.Request(url, headers=headers, callback=self.parse)

    def parse(self, response):
        # Extracting job titles
        job_titles = response.css('.job-title::text').extract()
        
        # Extracting median salaries
        median_salaries = response.css('.data-table .median-salary .salary-amount::text').extract()
        
        # Extracting job satisfaction scores
        satisfaction_scores = response.css('.data-table .satisfaction-score::text').extract()
        
        # Extracting job growth rates
        growth_rates = response.css('.data-table .job-growth-rate .rate::text').extract()

        # Create a DataFrame to store the extracted data
        df = pd.DataFrame({
            'Job Title': job_titles,
            'Median Salary': median_salaries,
            'Job Satisfaction Score': satisfaction_scores,
            'Job Growth Rate': growth_rates
        })

        # Print the DataFrame (optional)
        print(df)

        # You can also save the DataFrame to a CSV file if needed
        # df.to_csv('best_jobs_data.csv', index=False)
        reactor.stop()

# Run the spider in a separate process
process = CrawlerProcess()
process.crawl(BestJobsSpider)
process.start()
reactor.run()
# Out:
# 2024-03-30 11:50:12 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: scrapybot)
# 2024-03-30 11:50:12 [scrapy.utils.log] INFO: Versions: lxml 5.1.1.0, libxml2 2.12.6, cssselect 1.2.0, parsel 1.9.0, w3lib 2.1.2, Twisted 24.3.0, Python 3.12.2 (main, Mar 24 2024, 11:54:47) [GCC 11.4.0], pyOpenSSL 24.1.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.5, Platform Linux-6.1.75-060175-generic-x86_64-with-glibc2.35
# 2024-03-30 11:50:12 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-03-30 11:50:12 [py.warnings] WARNING: /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-03-30 11:50:12 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2024-03-30 11:50:12 [scrapy.extensions.telnet] INFO: Telnet Password: acd5226d44fbaf8e
# 2024-03-30 11:50:12 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2024-03-30 11:50:12 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2024-03-30 11:50:12 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-03-30 11:50:12 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-03-30 11:50:12 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-03-30 11:50:12 [scrapy.core.engine] INFO: Spider opened
# 2024-03-30 11:50:12 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-03-30 11:50:12 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6035
# 2024-03-30 11:51:12 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-03-30 11:52:12 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-03-30 11:53:12 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-03-30 11:53:12 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://money.usnews.com/careers/best-jobs/search> (failed 1 times): User timeout caused connection failure: Getting https://money.usnews.com/careers/best-jobs/search took longer than 180.0 seconds..
# 2024-03-30 11:53:15 [scrapy.crawler] INFO: Received SIGINT, shutting down gracefully. Send again to force
# 2024-03-30 11:53:15 [scrapy.core.engine] INFO: Closing spider (shutdown)

# %%
import pandas as pd
import scrapy
from scrapy.crawler import CrawlerProcess

class BestJobsSpider(scrapy.Spider):
    name = 'best_jobs_spider'
    
    # Define the URL to scrape
    start_urls = ['https://money.usnews.com/careers/best-jobs/search']

    def parse(self, response):
        # Extract data from the first 5 items
        jobs = response.css('.List__StyledList-hn9llu-0.cSUItl li')[:5]
        
        # Iterate over each job and extract relevant information
        for job in jobs:
            title = job.css('a ::text').get()
            median_salary = job.css('.jsx-2431333955 ::text').get()
            job_description = job.css('p ::text').get()

            yield {
                'Title': title.strip() if title else None,
                'Median Salary': median_salary.strip() if median_salary else None,
                'Job Description': job_description.strip() if job_description else None
            }

# Create a Scrapy CrawlerProcess
process = CrawlerProcess(settings={
    'FEED_FORMAT': 'csv',
    'FEED_URI': 'best_jobs.csv'
})

# Start the crawling process with our spider
process.crawl(BestJobsSpider)
process.start()
# Out:
# 2024-03-30 11:55:59 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: scrapybot)
# 2024-03-30 11:55:59 [scrapy.utils.log] INFO: Versions: lxml 5.1.1.0, libxml2 2.12.6, cssselect 1.2.0, parsel 1.9.0, w3lib 2.1.2, Twisted 24.3.0, Python 3.12.2 (main, Mar 24 2024, 11:54:47) [GCC 11.4.0], pyOpenSSL 24.1.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.5, Platform Linux-6.1.75-060175-generic-x86_64-with-glibc2.35
# 2024-03-30 11:55:59 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-03-30 11:55:59 [py.warnings] WARNING: /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-03-30 11:55:59 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2024-03-30 11:55:59 [scrapy.extensions.telnet] INFO: Telnet Password: 88449e8704ca0779
# 2024-03-30 11:55:59 [py.warnings] WARNING: /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/scrapy/extensions/feedexport.py:406: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2024-03-30 11:55:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-03-30 11:55:59 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2024-03-30 11:55:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-03-30 11:55:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-03-30 11:55:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-03-30 11:55:59 [scrapy.core.engine] INFO: Spider opened
# 2024-03-30 11:55:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-03-30 11:55:59 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6035
# 2024-03-30 11:55:59 [scrapy.core.engine] DEBUG: Crawled (403) <GET https://money.usnews.com/careers/best-jobs/search> (referer: None)
# 2024-03-30 11:55:59 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <403 https://money.usnews.com/careers/best-jobs/search>: HTTP status code is not handled or not allowed
# 2024-03-30 11:55:59 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-03-30 11:55:59 [scrapy.extensions.feedexport] INFO: Stored csv feed (0 items) in: best_jobs.csv
# 2024-03-30 11:55:59 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 241,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 1559,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/403': 1,
#  'elapsed_time_seconds': 0.240263,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 3, 30, 11, 55, 59, 739139, tzinfo=datetime.timezone.utc),
#  'httperror/response_ignored_count': 1,
#  'httperror/response_ignored_status_count/403': 1,
#  'log_count/DEBUG': 2,
#  'log_count/INFO': 12,
#  'log_count/WARNING': 2,
#  'memusage/max': 186474496,
#  'memusage/startup': 186474496,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2024, 3, 30, 11, 55, 59, 498876, tzinfo=datetime.timezone.utc)}
# 2024-03-30 11:55:59 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd
import scrapy
from scrapy.crawler import CrawlerProcess

class MySpider(scrapy.Spider):
    name = 'myspider'
    
    # Define the URL to scrape
    start_urls = ['https://money.usnews.com/careers/best-jobs/search']

    def parse(self, response):
        # Extract data from the first 5 job listings
        job_listings = response.css('a.job-title-link::text')[:5].extract()
        median_salaries = response.css('div.salary-container::text')[:5].extract()
        job_scores = response.css('div.job-score::text')[:5].extract()

        # Create a DataFrame to store the data
        df = pd.DataFrame({
            'Job Title': job_listings,
            'Median Salary': median_salaries,
            'Job Score': job_scores
        })

        # Save the DataFrame to a CSV file
        df.to_csv('job_data.csv', index=False)

# Create a Scrapy CrawlerProcess
process = CrawlerProcess(settings={
    'FEED_FORMAT': 'csv',
    'FEED_URI': 'job_data.csv'
})

# Start the crawling process with our spider
process.crawl(MySpider)
process.start()
# Out:
# 2024-03-30 11:57:15 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: scrapybot)
# 2024-03-30 11:57:15 [scrapy.utils.log] INFO: Versions: lxml 5.1.1.0, libxml2 2.12.6, cssselect 1.2.0, parsel 1.9.0, w3lib 2.1.2, Twisted 24.3.0, Python 3.12.2 (main, Mar 24 2024, 11:54:47) [GCC 11.4.0], pyOpenSSL 24.1.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.5, Platform Linux-6.1.75-060175-generic-x86_64-with-glibc2.35
# 2024-03-30 11:57:15 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-03-30 11:57:15 [py.warnings] WARNING: /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-03-30 11:57:15 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2024-03-30 11:57:15 [scrapy.extensions.telnet] INFO: Telnet Password: 476e4f401c338c35
# 2024-03-30 11:57:15 [py.warnings] WARNING: /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/scrapy/extensions/feedexport.py:406: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2024-03-30 11:57:15 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-03-30 11:57:15 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2024-03-30 11:57:15 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-03-30 11:57:15 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-03-30 11:57:15 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-03-30 11:57:15 [scrapy.core.engine] INFO: Spider opened
# 2024-03-30 11:57:15 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-03-30 11:57:15 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6036
# ---------------------------------------------------------------------------
# ReactorNotRestartable                     Traceback (most recent call last)
# /workspace/Python-Workbooks/scrapy/scrapy02.ipynb Cell 3 line 3
#      <a href='vscode-notebook-cell://harmkenn-pythonworkbook-9ars0whgk0k.ws-eu110.gitpod.io/workspace/Python-Workbooks/scrapy/scrapy02.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a> # Start the crawling process with our spider
#      <a href='vscode-notebook-cell://harmkenn-pythonworkbook-9ars0whgk0k.ws-eu110.gitpod.io/workspace/Python-Workbooks/scrapy/scrapy02.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a> process.crawl(MySpider)
# ---> <a href='vscode-notebook-cell://harmkenn-pythonworkbook-9ars0whgk0k.ws-eu110.gitpod.io/workspace/Python-Workbooks/scrapy/scrapy02.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a> process.start()
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/scrapy/crawler.py:429, in CrawlerProcess.start(self, stop_after_crawl, install_signal_handlers)
#     425 if install_signal_handlers:
#     426     reactor.addSystemEventTrigger(
#     427         "after", "startup", install_shutdown_handlers, self._signal_shutdown
#     428     )
# --> 429 reactor.run(installSignalHandlers=install_signal_handlers)
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/twisted/internet/base.py:693, in ReactorBase.run(self, installSignalHandlers)
#     692 def run(self, installSignalHandlers: bool = True) -> None:
# --> 693     self.startRunning(installSignalHandlers=installSignalHandlers)
#     694     try:
#     695         self.mainLoop()
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/twisted/internet/base.py:930, in ReactorBase.startRunning(self, installSignalHandlers)
#     928     raise error.ReactorAlreadyRunning()
#     929 if self._startedBefore:
# --> 930     raise error.ReactorNotRestartable()
#     932 self._signals.uninstall()
#     933 self._installSignalHandlers = installSignalHandlers
#
# ReactorNotRestartable:
