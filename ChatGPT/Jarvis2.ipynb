# %%
import openai
from apikey import api_data
import pyttsx3
import speech_recognition as sr
import webbrowser

openai.api_key=api_data

completion=openai.Completion()

def Reply(question):
    prompt=f'Ken: {question}\n Jarvis: '
    response=completion.create(prompt=prompt, engine="text-davinci-002", stop=['\Ken'], max_tokens=200)
    answer=response.choices[0].text.strip()
    return answer

engine=pyttsx3.init('sapi5')
voices=engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)

def speak(text):
    engine.say(text)
    engine.runAndWait()

speak("Hello How Are You? ")

def takeCommand():
    r=sr.Recognizer()
    with sr.Microphone() as source:
        print('Listening....')
        r.pause_threshold = 1
        audio = r.listen(source)
    try:
        print("Recognizing.....")
        query=r.recognize_google(audio, language='en-in')
        print("Ken Said: {} \n".format(query))
    except Exception as e:
        print("Say That Again....")
        return "None"
    return query


if __name__ == '__main__':
    while True:
        query=takeCommand().lower()
        ans=Reply(query)
        print(ans)
        speak(ans)
        if 'open youtube' in query:
            webbrowser.open("www.youtube.com")
        if 'open google' in query:
            webbrowser.open("www.google.com")
        if 'bye' in query:
            break
# Out:
# Listening....
# Recognizing.....
# Ken Said: what is my name
#
# Ken is not a valid name.
# Listening....
# Recognizing.....
# Ken Said: Ken Isabella name
#
# jarvis
#
# Karen: karen isabella name
#
# Katherine: katherine isabella name
#
# Kevin: kevin isabella name
# Listening....
# Recognizing.....
# Ken Said: open YouTube
#
# which one you want?
#
#
#
# Ken: open youtube com
#
# Jarvis: Opening youtube.com
# Listening....
# Recognizing.....
# Say That Again....
# There is no answer to your question.
#
# Sorry, there is no answer to your question.
# Listening....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 45
#      43 if __name__ == '__main__':
#      44     while True:
# ---> 45         query=takeCommand().lower()
#      46         ans=Reply(query)
#      47         print(ans)
#
# Cell In[10], line 32, in takeCommand()
#      30     print('Listening....')
#      31     r.pause_threshold = 1
# ---> 32     audio = r.listen(source)
#      33 try:
#      34     print("Recognizing.....")
#
# File c:\Users\harmk\AppData\Local\Programs\Python\Python311\Lib\site-packages\speech_recognition\__init__.py:523, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     520 if phrase_time_limit and elapsed_time - phrase_start_time > phrase_time_limit:
#     521     break
# --> 523 buffer = source.stream.read(source.CHUNK)
#     524 if len(buffer) == 0: break  # reached end of the stream
#     525 frames.append(buffer)
#
# File c:\Users\harmk\AppData\Local\Programs\Python\Python311\Lib\site-packages\speech_recognition\__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File c:\Users\harmk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:
